# %% [markdown]
# <a href="https://colab.research.google.com/github/silva93felipe/ProjetoFinal/blob/master/ProFinal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#fonte https://g1.globo.com/economia/tecnologia/noticia/2020/06/11/com-maior-uso-da-internet-durante-pandemia-numero-de-reclamacoes-aumenta-especialistas-apontam-problemas-mais-comuns.ghtml


import matplotlib.pyplot as plt

print("""O uso da internet no Brasil cresceu durante a quarentena: o aumento foi entre 40% e 50%,
segundo dados da Agência Nacional de Telecomunicações (Anatel)...""")

#eixos
x3 = [0, 40, 50] #Valor do aumento para o eixo x, poderia ser no y mas achei interessante ser no x, deixando o y com o período
y3 = ['Março', 'Abril', 'Maio']

#Uni os eixos
plt.plot(x3, y3) 

#legendas
plt.title('Uso de internet no Brasil') #título para o gráfico
plt.xlabel('(%)') #lengenda para o eixo x
plt.ylabel('Período') #lengenda para o eixo y

#Mostra o gráfico
plt.show() 

print("""Em março, a Anatel registrou 67 mil reclamações relativas a banda larga... 
Em abril, o volume passou de 74 mil e em maio o número foi semelhante,
com mais de 73 mil queixas. No ano passado, 
houve 50 mil reclamações em março, 48 mil em abril e 47 mil em maio.""")

#eixos
y2 = [50, 48, 47]
x2 = ['Março', 'Abril', 'Maio']
y = [67, 74, 73]
x = ['Março', 'Abril', 'Maio']

#Uni os eixos
plt.plot(x, y, 'r', label='2020', linewidth=2) # O parâmetro linewidth mexe com a largura da reta
plt.plot(x2, y2, 'g', label='2019', linewidth=2)

#legendas
plt.xlabel('Período')
plt.ylabel('Mil')
plt.title('Reclamações')
plt.legend() #Essa função permite que a legenda interna que está parametrizada no plt.plot(label='algo') apareça.

#Mostra o gráfico
plt.show()

print("""O site ReclameAqui... contendo o termo “internet” 
crescer: de 12 mil em março para mais de 14 mil em abril.
...""")

#colunas
plt.bar(['Março'], [12], color='g') #coloquei uma cor para dá um ênfase na diferença com o parâmetro 'color'
plt.bar(['Abril'], [14], color='red')

#legendas
plt.xlabel('Período')
plt.ylabel('Mil')
plt.title('Site ReclameAqui')

#Mostra o gráfico
plt.show()

#Por que para cada gráfico eu coloquei um plt.show? Poderia ter colocado só um? Ao colocar só um ele uni todos os gráficos trazendo problema
# Out:
# O uso da internet no Brasil cresceu durante a quarentena: o aumento foi entre 40% e 50%,
# segundo dados da Agência Nacional de Telecomunicações (Anatel)...
# Em março, a Anatel registrou 67 mil reclamações relativas a banda larga...
# Em abril, o volume passou de 74 mil e em maio o número foi semelhante,
# com mais de 73 mil queixas. No ano passado,
# houve 50 mil reclamações em março, 48 mil em abril e 47 mil em maio.
# O site ReclameAqui... contendo o termo “internet”
# crescer: de 12 mil em março para mais de 14 mil em abril.
# ...
